# %%
# Q1

import tkinter as tk

win = tk.Tk()
win.geometry("300x200")


regL = tk.Label(win,text="regno")
regL.grid(row=0,column=0)
regIN = tk.Entry(win)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,text="Name")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,text="Dept")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win)
deptIN.grid(row=2,column=1)

gen = tk.IntVar()
genderL = tk.Label(win,text="gender")
genderL.grid(row=3,column=0)
male = tk.Radiobutton(win,text="male",value="male",variable=gen)
male.grid(row=3,column=1)
female = tk.Radiobutton(win,text="female",value="female",variable=gen)
female.grid(row=3,column=2)


ageL = tk.Label(win,text="Age")
ageL.grid(row=4,column=0)
ageIN = tk.Spinbox(win,from_=0,to=30)
ageIN.grid(row=4,column=1)

insert=tk.Button(win,text="insert")
insert.grid(row=5,column=1,pady=10)

update=tk.Button(win,text="update")
update.grid(row=5,column=2,pady=10)

delete=tk.Button(win,text="delete")
delete.grid(row=6,column=1,pady=10)

select=tk.Button(win,text="select")
select.grid(row=6,column=2,pady=10)

win.mainloop()

# %%
# Q2    
import tkinter as tk

win = tk.Tk()
#win.geometry("350x250")


regL = tk.Label(win,text="Custid")
regL.grid(row=0,column=0)
regIN = tk.Entry(win)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,text="CustomerName")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,text="Branch")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win)
deptIN.grid(row=2,column=1)

gen = tk.IntVar()
genderL = tk.Label(win,text="account type")
genderL.grid(row=3,column=0)
male = tk.Radiobutton(win,text="saving",value="saving",variable=gen)
male.grid(row=3,column=1)
female = tk.Radiobutton(win,text="Non saving",value="Non saving",variable=gen)
female.grid(row=3,column=2)


ageL = tk.Label(win,text="Amount")
ageL.grid(row=4,column=0)
ageIN = tk.Scale(win,from_=0,to=30,orient="horizontal")
ageIN.grid(row=4,column=1)

insert=tk.Button(win,text="insert")
insert.grid(row=5,column=0,pady=10)

update=tk.Button(win,text="update")
update.grid(row=5,column=1,pady=10)

delete=tk.Button(win,text="delete")
delete.grid(row=6,column=0,pady=10)

select=tk.Button(win,text="select")
select.grid(row=6,column=1,pady=10)

win.mainloop()

# %%
# Q3
import tkinter as tk

win = tk.Tk()
#win.geometry("300x200")


regL = tk.Label(win,text="Empid")
regL.grid(row=0,column=0)
regIN = tk.Entry(win)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,text="Employee Name")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,text="Job")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win)
deptIN.grid(row=2,column=1)

gen = tk.IntVar()
genderL = tk.Label(win,text="Employee type")
genderL.grid(row=3,column=0)
male = tk.Radiobutton(win,text="Regular",value="Regular",variable=gen)
male.grid(row=3,column=1)
female = tk.Radiobutton(win,text="Temporary",value="Temporary",variable=gen)
female.grid(row=3,column=2)


ageL = tk.Label(win,text="Salary")
ageL.grid(row=4,column=0)
ageIN = tk.Spinbox(win,from_=0,to=30)
ageIN.grid(row=4,column=1)

insert=tk.Button(win,text="insert")
insert.grid(row=5,column=0,pady=10)

update=tk.Button(win,text="update")
update.grid(row=5,column=1,pady=10)

delete=tk.Button(win,text="delete")
delete.grid(row=6,column=0,pady=10)

select=tk.Button(win,text="select")
select.grid(row=6,column=1,pady=10)

win.mainloop()

# %%
# Q4
import tkinter as tk

win = tk.Tk()
#win.geometry("300x200")


regL = tk.Label(win,text="Bookingid")
regL.grid(row=0,column=0)
regIN = tk.Entry(win)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,text="Passenger Name")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,text="Flight")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win)
deptIN.grid(row=2,column=1)

gen = tk.IntVar()
genderL = tk.Label(win,text="Source")
genderL.grid(row=3,column=0)
male = tk.Radiobutton(win,text="Delhi",value="Delhi",variable=gen)
male.grid(row=3,column=1)
female = tk.Radiobutton(win,text="Mumbai",value="Mumbai",variable=gen)
female.grid(row=3,column=2)

dest = tk.IntVar()
genderL = tk.Label(win,text="Destination")
genderL.grid(row=3,column=3)
dest1 = tk.Radiobutton(win,text="Delhi",value="Delhi",variable=dest)
dest1.grid(row=3,column=4)
dest2 = tk.Radiobutton(win,text="Mumbai",value="Mumbai",variable=dest)
dest2.grid(row=3,column=5)

ageL = tk.Label(win,text="Duration")
ageL.grid(row=4,column=0)
ageIN = tk.Spinbox(win,from_=0,to=30)
ageIN.grid(row=4,column=1)

insert=tk.Button(win,text="insert")
insert.grid(row=5,column=0,pady=10)

update=tk.Button(win,text="update")
update.grid(row=5,column=1,pady=10)

delete=tk.Button(win,text="delete")
delete.grid(row=6,column=0,pady=10)

select=tk.Button(win,text="select")
select.grid(row=6,column=1,pady=10)
 
win.mainloop()

# %%
# Q5
import tkinter as tk

win = tk.Tk()
#win.geometry("300x200")


regL = tk.Label(win,text="Movie Booking id")
regL.grid(row=0,column=0)
regIN = tk.Entry(win)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,text="person Name")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,text="Movie name")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win)
deptIN.grid(row=2,column=1)

gen = tk.IntVar()
genderL = tk.Label(win,text="class")
genderL.grid(row=3,column=0)
male = tk.Radiobutton(win,text="A",value="A",variable=gen)
male.grid(row=3,column=1)
female = tk.Radiobutton(win,text="B",value="B",variable=gen)
female.grid(row=3,column=2)

dest = tk.StringVar()
dest_s = tk.StringVar()
genderL = tk.Label(win,text="Time of show")
genderL.grid(row=3,column=3)
dest1 = tk.Checkbutton(win,text="Delhi",offvalue=0,onvalue=1,variable=dest)
dest1.deselect()
dest1.grid(row=3,column=4)
dest2 = tk.Checkbutton(win,text="Mumbai",offvalue=0,onvalue=1,variable=dest_s)
dest2.deselect()
dest2.grid(row=3,column=5)

ageL = tk.Label(win,text="No of Tickets")
ageL.grid(row=4,column=0)
ageIN = tk.Scale(win,from_=0,to=30,orient="horizontal")
ageIN.grid(row=4,column=1)

insert=tk.Button(win,text="insert")
insert.grid(row=5,column=0,pady=10)

update=tk.Button(win,text="update")
update.grid(row=5,column=1,pady=10)

delete=tk.Button(win,text="delete")
delete.grid(row=6,column=0,pady=10)

select=tk.Button(win,text="select")
select.grid(row=6,column=1,pady=10)

win.mainloop()

# %%
# Q6

import tkinter as tk

win= tk.Tk()
rate = tk.Label(win,text="Annual rate")
rate.grid(row=0,column=0)
rateIN = tk.Entry(win)
rateIN.grid(row=0,column=2)

payment = tk.Label(win,text="Number of payments")
payment.grid(row=1,column=0)
paymentIN = tk.Entry(win)
paymentIN.grid(row=1,column=2)

Loan = tk.Label(win,text="Loan principle")
Loan.grid(row=2,column=0)
LoanIN = tk.Entry(win)
LoanIN.grid(row=2,column=2)

Monthly = tk.Label(win,text="Monthly payment")
Monthly.grid(row=4,column=0)
MonthlyIN = tk.Entry(win)
MonthlyIN.grid(row=4,column=2)

Remaining = tk.Label(win,text="Remaining Loan")
Remaining.grid(row=5,column=0)
RemainingIN = tk.Entry(win)
RemainingIN.grid(row=5,column=2)

balance = tk.Button(win,text="Final Balance")
balance.grid(row=6,column=0)
Monthly_payment = tk.Button(win,text="Monthly payment")
Monthly_payment.grid(row=6,column=1)
Quit = tk.Button(win,text="Quit")
Quit.grid(row=6,column=2)

win.mainloop()

# %%
# Q7
import tkinter as tk

win = tk.Tk()
# win.geometry("400x400")



contactL = tk.Label(win,text="Contact List")
contactL.grid(row=0,column=0)
txtarea = tk.Text(win,width=20,height=10)
txtarea.grid(row=1,column=0,rowspan=7,padx=50)
disp = tk.Button(win,text="Display Contact")
disp.grid(row=8,column=0)

newconL = tk.Label(win,text="New Contact")
newconL.grid(row=0,column=1,columnspan=2)
first = tk.Label(win,text="First Name")
first.grid(row=1,column=1)
firstIN = tk.Entry(win)
firstIN.grid(row=1,column=2)
last = tk.Label(win,text="Last Name")
last.grid(row=2,column=1)
lastIN = tk.Entry(win)
lastIN.grid(row=2,column=2)
Phone = tk.Label(win,text="Phone #")
Phone.grid(row=3,column=1)
PhoneIN = tk.Entry(win)
PhoneIN.grid(row=3,column=2)
friend = tk.Checkbutton(win,text="Friend")
friend.grid(row=4,column=1,columnspan=2)
Email = tk.Label(win,text="Email")
Email.grid(row=5,column=1)
EmailIN = tk.Entry(win)
EmailIN.grid(row=5,column=2)
Birthday = tk.Label(win,text="Birthday")
Birthday.grid(row=6,column=1)
BirthdayIN = tk.Entry(win)
BirthdayIN.grid(row=6,column=2)
add = tk.Button(win,text="Add Contact")
add.grid(row=7,column=2)

# print(win.)
bframe = tk.Frame(win)
bframe.grid(row=9,pady=10,columnspan=3)
lname = tk.Label(bframe,text="Last Name")
lname.grid(row=0,column=0)
lnameIN = tk.Entry(bframe)
lnameIN.grid(row=0,column=1)
rtext = tk.Label(bframe,text="Result:\nLast,First,\nPhone")
rtext.grid(row=0,column=2,padx=100)

search = tk.Button(bframe,text="Search")
search.grid(row=2,column=1)


win.mainloop()

# %%
# Q8
# Q1

import tkinter as tk

win = tk.Tk()
win.geometry("500x300")
win.configure(background="light green")
win.title("registration form")

regL = tk.Label(win,background="light green",text="Name")
regL.grid(row=0,column=0)
regIN = tk.Entry(win,width=50)
regIN.grid(row=0,column=1)


nameL = tk.Label(win,background="light green",text="Course")
nameL.grid(row=1,column=0)
nameIN = tk.Entry(win,width=50)
nameIN.grid(row=1,column=1)


deptL = tk.Label(win,background="light green",text="Semester")
deptL.grid(row=2,column=0)
deptIN = tk.Entry(win,width=50)
deptIN.grid(row=2,column=1)

FormL = tk.Label(win,background="light green",text="Form No")
FormL.grid(row=3,column=0)
FormIN = tk.Entry(win,width=50)
FormIN.grid(row=3,column=1)

ContactL = tk.Label(win,background="light green",text="Contact no")
ContactL.grid(row=4,column=0)
ContactIN = tk.Entry(win,width=50)
ContactIN.grid(row=4,column=1)

emailL = tk.Label(win,background="light green",text="Email ID")
emailL.grid(row=5,column=0)
emailIN = tk.Entry(win,width=50)
emailIN.grid(row=5,column=1)

addL = tk.Label(win,background="light green",text="address")
addL.grid(row=6,column=0)
addIN = tk.Entry(win,width=50)
addIN.grid(row=6,column=1)

insert=tk.Button(win,text="Submit",background="red")
insert.grid(row=7,column=1,pady=10)



win.mainloop()

# %%
# Q10
import tkinter as tk

win = tk.Tk()
name = tk.Label(win,text="Name")
name.grid(row=0,column=0)
nameIN = tk.Entry(win)
nameIN.grid(row=0,column=1)

Phone = tk.Label(win,text="Phone")
Phone.grid(row=1,column=0)
PhoneIN = tk.Entry(win)
PhoneIN.grid(row=1,column=1)

add = tk.Button(win,text="ADD")
add.grid(row=2,column=0)
update = tk.Button(win,text="Update")
update.grid(row=2,column=1)
delete = tk.Button(win,text="Delete")
delete.grid(row=2,column=2)

listbox = tk.Listbox(win)
listbox.grid(row=3,column=0)
for values in range(100):
    listbox.insert(tk.END, values)

scrollbar = tk.Scrollbar(win,bg="red")
scrollbar.grid(row=3,column=1,sticky=tk.N+tk.W+tk.S)
listbox.config(yscrollcommand=scrollbar.set)
scrollbar.config(command = listbox.yview)

win.mainloop()

# %%
'''
Here the TreeView widget is configured as a multi-column listbox
with adjustable column width and column-header-click sorting.
'''
try:
    import Tkinter as tk
    import tkFont
    import ttk
except ImportError:  # Python 3
    import tkinter as tk
    import tkinter.font as tkFont
    import tkinter.ttk as ttk

class MultiColumnListbox(object):
    """use a ttk.TreeView as a multicolumn ListBox"""

    def __init__(self):
        self.tree = None
        self._setup_widgets()
        self._build_tree()

    def _setup_widgets(self):
        s = """\click on header to sort by that column
to change width of column drag boundary
        """
        msg = ttk.Label(wraplength="4i", justify="left", anchor="n",
            padding=(10, 2, 10, 6), text=s)
        msg.pack(fill='x')
        container = ttk.Frame()
        container.pack(fill='both', expand=True)
        # create a treeview with dual scrollbars
        self.tree = ttk.Treeview(columns=car_header, show="headings")
        vsb = ttk.Scrollbar(orient="vertical",
            command=self.tree.yview)
        hsb = ttk.Scrollbar(orient="horizontal",
            command=self.tree.xview)
        self.tree.configure(yscrollcommand=vsb.set,
            xscrollcommand=hsb.set)
        self.tree.grid(column=0, row=0, sticky='nsew', in_=container)
        vsb.grid(column=1, row=0, sticky='ns', in_=container)
        hsb.grid(column=0, row=1, sticky='ew', in_=container)
        container.grid_columnconfigure(0, weight=1)
        container.grid_rowconfigure(0, weight=1)

    def _build_tree(self):
        for col in car_header:
            self.tree.heading(col, text=col.title(),
                command=lambda c=col: sortby(self.tree, c, 0))
            # adjust the column's width to the header string
            self.tree.column(col,
                width=tkFont.Font().measure(col.title()))

        for item in car_list:
            self.tree.insert('', 'end', values=item)
            # adjust column's width if necessary to fit each value
            for ix, val in enumerate(item):
                col_w = tkFont.Font().measure(val)
                if self.tree.column(car_header[ix],width=None)<col_w:
                    self.tree.column(car_header[ix], width=col_w)

def sortby(tree, col, descending):
    """sort tree contents when a column header is clicked on"""
    # grab values to sort
    data = [(tree.set(child, col), child) \
        for child in tree.get_children('')]
    # if the data to be sorted is numeric change to float
    #data =  change_numeric(data)
    # now sort the data in place
    data.sort(reverse=descending)
    for ix, item in enumerate(data):
        tree.move(item[1], '', ix)
    # switch the heading so it will sort in the opposite direction
    tree.heading(col, command=lambda col=col: sortby(tree, col, \
        int(not descending)))

# the test data ...

car_header = ['car', 'repair']
car_list = [
('Hyundai', 'brakes') ,
('Honda', 'light') ,
('Lexus', 'battery') ,
('Benz', 'wiper') ,
('Ford', 'tire') ,
('Chevy', 'air') ,
('Chrysler', 'piston') ,
('Toyota', 'brake pedal') ,
('BMW', 'seat')
]


if __name__ == '__main__':
    root = tk.Tk()
    root.title("Multicolumn Treeview/Listbox")
    listbox = MultiColumnListbox()
    root.mainloop()

# %%
# Q12

import tkinter as tk
win = tk.Tk()
win.title("PythonGuides")

fullname = tk.Label(win,text="Full Name")
fullname.grid(row=0,column=0)
fullnameIN = tk.Entry(win)
fullnameIN.grid(row=0,column=1)
Email = tk.Label(win,text="Email")
Email.grid(row=1,column=0)
EmailIN = tk.Entry(win)
EmailIN.grid(row=1,column=1)
password = tk.Label(win,text="Password")
password.grid(row=2,column=0)
passwordIN = tk.Entry(win,show="*")
passwordIN.grid(row=2,column=1)

fieldset = tk.LabelFrame(win, text="Here goes the label",width=100,height=100,relief=tk.SUNKEN,bd=5)  
fieldset.grid(row=3,column=1)

gen = tk.IntVar()
male=tk.Radiobutton(fieldset,text="Male",value="male",variable=gen,command="")
male.grid(row=0,column=0)
female=tk.Radiobutton(fieldset,value="female",text="female",variable=gen,command="")
female.grid(row=1,column=0)
other=tk.Radiobutton(fieldset,text="other",value="other",variable=gen,command="")
other.grid(row=2,column=0)

terms = tk.Checkbutton(win,text="Accept the terms & condition")
terms.grid(row=4,column=0,columnspan=2)
submit = tk.Button(win,text="submit")
submit.grid(row=5,column=1)
win.mainloop()

# %%
# Import only those methods
# which are mentioned below, this way of
# importing methods is efficient
from tkinter import Tk, mainloop, LEFT, TOP
from tkinter.ttk import *

# Creating tkinter window with fixed geometry
root = Tk()
root.geometry('250x150')

# This will create a LabelFrame
label_frame = LabelFrame(root, text = 'This is Label Frame')
label_frame.pack(expand = 'yes', fill = 'both')

# Buttons
btn1 = Button(label_frame, text = 'Button 1')
btn1.place(x = 30, y = 10)
btn2 = Button(label_frame, text = 'Button 2')
btn2.place(x = 130, y = 10)

# Checkbuttons
chkbtn1 = Checkbutton(label_frame, text = 'Checkbutton 1')
chkbtn1.place(x = 30, y = 50)
chkbtn2 = Checkbutton(label_frame, text = 'Checkbutton 2')
chkbtn2.place(x = 30, y = 80)

# This creates infinite loop which generally
# waits for any interrupt (like keyboard or
# mouse) to terminate
mainloop()

# %% [markdown]
# # FROM 09 CALCULATOR

# %%
# Program9: Calculator
from tkinter import *
m=Tk()
m.geometry("312x338")
m.resizable(0,0)
m.title("Calculator")
def _click(item):
    global exp
    exp=exp+str(item)
    input_text.set(exp)
def _clear():
    global exp
    exp=""
    input_text.set("0")
def _equal():
    global exp
    result = str(eval(exp))
    input_text.set(result)
    exp=""
exp=""
input_text=StringVar()
frame=Frame(m,width=312, height=50, bd=0, highlightbackground="light grey",highlightcolor="black",highlightthickness=8)
frame.pack(side=TOP)
a= Entry(frame,font=('arial',18,'bold'), textvariable=input_text, width=50,bg="white",bd=0,justify=RIGHT)
a.grid(row=0,column=0)
a.pack(ipady=10)
b= Frame(m, width=312, height=272.5, bg="grey")
b.pack()
#first row
Button(b, text="C", fg="black", width=10, height=3, bd=0,bg="light grey",cursor="hand2",font=("Arial",9,"bold"),command= lambda: _clear()).grid(row=0,column=0,padx=1,pady=1)
Button(b, text="√", fg="black", width=10, height=3, bd=0,bg="light grey",cursor="hand2",font=("Arial",9,"bold"),command= lambda: _click("**0.5")).grid(row=0,column=1,padx=1,pady=1)
Button(b, text="x^y", fg="black", width=10, height=3, bd=0,bg="light grey",cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click("**")).grid(row=0,column=2,padx=1,pady=1)
Button(b, text="%", fg="black", width=10, height=3, bd=0,bg="light grey",cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click("%")).grid(row=0,column=3,padx=1,pady=1)
#second row
one= Button(b, text="1", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(1)).grid(row=1,column=0,padx=1,pady=1)
two= Button(b, text="2", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(2)).grid(row=1,column=1,padx=1,pady=1)
three= Button(b, text="3", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(3)).grid(row=1,column=2,padx=1,pady=1)
plus= Button(b, text="+", fg="black", width=10, height=3, bd=0,bg="light grey",font=("Arial",9,"bold"),cursor="hand2",command= lambda:_click("+")).grid(row=1,column=3,padx=1, pady=1)
#third row
four= Button(b, text="4", fg="black", width=10, height=3, bd=0, cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(4)).grid(row=2,column=0,padx=1,pady=1)
five= Button(b, text="5", fg="black", width=10, height=3, bd=0, cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(5)).grid(row=2,column=1,padx=1,pady=1)
six= Button(b, text="6", fg="black", width=10, height=3, bd=0, cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(6)).grid(row=2,column=2,padx=1, pady=1)
minus= Button(b, text="-", fg="black", width=10, height=3, bd=0, bg="light grey",font=("Arial",9,"bold"),cursor="hand2",command= lambda:_click("-")).grid(row=2,column=3,padx=1,pady=1)
#fourth row
seven= Button(b, text="7", fg="black", width=10, height=3, bd=0, cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(7)).grid(row=3,column=0,padx=1, pady=1)
eight= Button(b, text="8", fg="black", width=10, height=3, bd=0, cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(8)).grid(row=3,column=1,padx=1, pady=1)
nine= Button(b, text="9", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command= lambda:_click(9)).grid(row=3,column=2,padx=1,pady=1)
prod= Button(b, text="", fg="black", width=10, height=3, bd=0, bg="light grey",font=("Arial",9,"bold"),cursor="hand2",command= lambda:_click("")).grid(row=3,column=3,padx=1,pady=1)
#fifth row
zero= Button(b, text="0", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command = lambda: _click(0)).grid(row=4,column=0,padx=1,pady=1)
dot= Button(b, text=".", fg="black", width=10, height=3, bd=0,cursor="hand2",font=("Arial",9,"bold"),command = lambda: _click(".")).grid(row=4,column=1,padx=1,pady=1)
equal= Button(b, text="=", fg="black", width=10, height=3, bd=0, bg="orange",font=("Arial",9,"bold"),cursor="hand2",command = lambda: _equal()).grid(row=4,column=2,padx=1,pady=1)
divide= Button(b, text="/", fg="black", width=10, height=3, bd=0,bg="light grey",font=("Arial",9,"bold"),cursor="hand2",command = lambda: _click("/")).grid(row=4,column=3,padx=1,pady=1)

m.mainloop()

# %%
#Program10: Phone List
m=Tk()
m.geometry("400x400")
m.resizable(1,1)
m.title("Phone List")
Label(m,text="Name").grid(row=0,column=0,padx=30,pady=5,sticky=NW)
Entry(m,width=30).grid(row=0,column=1)
Label(m,text="Phone").grid(row=1,column=0,pady=5)
Entry(m,width=30).grid(row=1,column=1)
#Button(m,text="Add").grid(row=2,column=0,pady=5)
#Button(m,text="Update").grid(row=2,column=1)
#Button(m,text="Delete").grid(row=2,column=2)
Button(m,text="Add",width=8).place(x=40,y=80)
Button(m,text="Update",width=8).place(x=120,y=80)
Button(m,text="Delete",width=8).place(x=200,y=80)
#Scrollbar(m).grid(row=3,column=1,sticky=S,pady=5)
scroll=Scrollbar(m)
scroll.place(x=333,y=130)
a= ttk.Treeview(m,yscrollcommand=scroll.set,xscrollcommand= scroll.set)
a.place(x=30,y=140)
scroll.config(command=a.yview)
#scroll.config(command=a.xview)
a['columns'] = ('name', 'phone'," ")
# format our column
a.column("#0", width=0, stretch=NO)
a.column("name",anchor=CENTER, width=130)
a.column("phone",anchor=CENTER, width=100)
a.column(" ",anchor=CENTER,width=80)
#heading
a.heading("#0",text="",anchor=CENTER)
a.heading("name",text="Name",anchor=CENTER)
a.heading("phone",text="Phone",anchor=CENTER)
a.heading(" ",text=" ",anchor=CENTER)
#add data
a.insert(parent='',index='end',iid=0,text='',values=("Bornhart, Ralph","683-2341"))
a.insert(parent='',index='end',iid=1,text='',values=("Jones, Janet","483-5432"))
a.insert(parent='',index='end',iid=2,text='',values=("Meyers, Chris","343-4349"))
a.insert(parent='',index='end',iid=3,text='',values=("Nelson, Eric","485-2689"))
a.insert(parent='',index='end',iid=4,text='',values=("Prefect, Ford","987-6543"))
a.insert(parent='',index='end',iid=5,text='',values=("Smith, Bob","689-1234"))
a.insert(parent='',index='end',iid=6,text='',values=("Smith, Robert","689-1234"))
a.insert(parent='',index='end',iid=7,text='',values=("Bornhart, Ralph","683-2341"))
a.insert(parent='',index='end',iid=8,text='',values=("Jones, Janet","483-5432"))
a.insert(parent='',index='end',iid=9,text='',values=("Meyers, Chris","343-4349"))
a.insert(parent='',index='end',iid=10,text='',values=("Nelson, Eric","485-2689"))
a.insert(parent='',index='end',iid=11,text='',values=("Prefect, Ford","987-6543"))
a.insert(parent='',index='end',iid=12,text='',values=("Smith, Bob","689-1234"))
a.insert(parent='',index='end',iid=13,text='',values=("Smith, Robert","689-1234"))
a.place(x=20,y=130)
m.mainloop()

# %%
#Program11:Billing Details
m=Tk()
m.geometry("390x400")
m.title("Billing")
Label(m,text="Name: ").grid(row=0,column=0,padx=10)
Entry(m,width=30).grid(row=0,column=1)
Label(m,text="Products:").grid(row=1,column=0,padx=10,sticky=S)
a= Text(m,height=6,width=23)
a.insert(INSERT,"Items             Price\n\nPen                10/-\nPencil             5/-\nEraser             10/-\nSharpener          15/-")
a.grid(row=1,column=1,padx=50,rowspan=7,pady=10)
Label(m,text="Quantity: ").grid(row=8,column=0)
Entry(m,width=30).grid(row=8,column=1,pady=10,padx=10)
Button(m,text="Add Items",width=15).place(x=197,y=180)
Text(m,height=6,width=30).place(x=70,y=220)
Button(m,text="Clear Items",width=15).place(x=59,y=330)
Button(m,text="Total",width=15).place(x=210,y=330)
m.mainloop()

# %%
import tkinter as tk
#Program12: Python Guides
m=tk.Tk()
m.geometry("400x350")
m.title("PythonGuides")
l1=tk.Label(m,text="Full Name")
l1.grid(row=0,column=0,padx=20,pady=5)
e1=tk.Entry(m,width=30)
e1.grid(row=0,column=1)
l2=tk.Label(m,text="Email")
l2.grid(row=1,column=0)
e2=tk.Entry(m,width=30)
e2.grid(row=1,column=1)
l3=tk.Label(m,text="Password")
l3.grid(row=2,column=0,pady=5)
e3=tk.Entry(m,width=30)
e3.grid(row=2,column=1)
lf=tk.LabelFrame(m,text="Gender",width=200,height=100,bd=5)
lf.grid(row=3,column=1)
var=tk.IntVar()
r1=tk.Radiobutton(lf,text="Female",value="Female",variable=var)
r1.grid(row=0,column=0,padx=3,pady=5)
r2=tk.Radiobutton(lf,text="Male",value="Male",variable=var)
r2.grid(row=1,column=0,padx=7,pady=5)
r3=tk.Radiobutton(lf,text="Others",value="Others",variable=var)
r3.grid(row=2,column=0,padx=5,pady=5)
c=tk.Checkbutton(m,text="Accept the terms & conditions")
c.grid(row=4,column=0,columnspan=2,pady=10)
b=tk.Button(m,text="Submit",width=20)
b.grid(row=5,column=1,pady=5)
m.mainloop()

# %%
#Program13: Bookstore Management
m=Tk()
m.title("BookStore Management Software")
m.geometry("540x400")
Label(m,text="Title").place(x=30,y=20)
Entry(m,width=25).place(x=80,y=22)
Label(m,text="Author").place(x=260,y=20)
Entry(m,width=25).place(x=330,y=22)
Label(m,text="Year").place(x=30,y=70)
Entry(m,width=25).place(x=80,y=70)
Label(m,text="ISBN").place(x=270,y=70)
Entry(m,width=25).place(x=330,y=70)
#scrollbar
scroll=Scrollbar(m)
scroll.place(x=370,y=120)
scroll=Scrollbar(m,orient='horizontal',width=10)
scroll.place(x=280,y=356)
a= ttk.Treeview(m,yscrollcommand=scroll.set,xscrollcommand= scroll.set)
a.place(x=30,y=140)
scroll.config(command=a.yview)
scroll.config(command=a.xview)
a['columns'] = ('book_id', 'book_title', 'book_author', 'book_year', 'book_isbn')
# format our column
a.column("#0", width=0, stretch=NO)
a.column("book_id",anchor=CENTER, width=40)
a.column("book_title",anchor=CENTER,width=80)
a.column("book_author",anchor=CENTER,width=80)
a.column("book_year",anchor=CENTER,width=60)
a.column("book_isbn",anchor=CENTER,width=90)
#heading
a.heading("#0",text="",anchor=CENTER)
a.heading("book_id",text="ID",anchor=CENTER)
a.heading("book_title",text="Title",anchor=CENTER)
a.heading("book_author",text="Author",anchor=CENTER)
a.heading("book_year",text="Year",anchor=CENTER)
a.heading("book_isbn",text="ISBN",anchor=CENTER)
#add data
a.insert(parent='',index='end',iid=0,text='',values=('1','The Earth','ani','2012','4545664551536'))
a.insert(parent='',index='end',iid=1,text='',values=('2','The Moon','Aniruddha','2016','5545446546646846'))
a.place(x=20,y=130)
Button(m,text="View All",width=15).place(x=390,y=130)
Button(m,text="Search",width=15).place(x=390,y=170)
Button(m,text="Add Entry",width=15).place(x=390,y=210)
Button(m,text="Update Selected ",width=15).place(x=390,y=250)
Button(m,text="Delete Selected",width=15).place(x=390,y=290)
Button(m,text="Close",width=15).place(x=390,y=330)
m.mainloop()

# %%
#Program14: Currency Converter
m=Tk()
m.geometry("500x350")
m.title("Python Project")
def _click():
    t=input_text.get()
    if(val1.get()=="USD"):
        val=t*74.93
    else:
        val=t/(74.93)
    b.delete(0,END)
    b.insert(0,val)

input_text=IntVar()
text=Entry(m,fg="white",bg="blue",font=("Arial",18),justify=CENTER)
text.place(x=0,y=0,width=500,height=40)
text.insert(0,"Welcome to Real Time Currency Converter")
Label(m,text="1 USD= 74.93 Indian Rupee",font=("Arial",17,'bold')).place(x=95,y=50)
Label(m,text="Date: 2020-07-22",font=("Arial",17,'bold')).place(x=150,y=90)
option1=["USD","INR"]
val1= StringVar(m)
val1.set("USD")
o1=OptionMenu(m,val1,*option1)
o1.place(x=80,y=150)
o1.configure(bg="white",width=15)
option2=["INR","USD"]
val2= StringVar(m)
val2.set("INR")
o2=OptionMenu(m,val2,*option2)
o2.place(x=290,y=150)
o2.configure(bg="white",width=15)
a=Entry(m,width=15,justify=CENTER,textvariable=input_text)
a.place(x=98,y=190)
b= Entry(m, width=15,justify=CENTER)
b.place(x=310, y=190)
c=Button(m,text="Convert",width=12,height=1,justify=CENTER,font=("Arial",13,"italic"),bg="light blue",fg="white",command=lambda:_click())
c.place(x=182,y=229)
m.mainloop()

# %%
from tkinter import tk
#Program15: Python GUI
m=Tk()
m.geometry("450x400")
m.title("Python GUI")
menubar= Menu(m,background='#ff8000', foreground='black', activebackground='white', activeforeground='black')
file = Menu(menubar,tearoff=1,foreground='black')
file.add_command(label="New")
file.add_command(label="Open")
file.add_command(label="Save")
file.add_command(label="Save as")
file.add_separator()
file.add_command(label="Exit",command=m.quit)
menubar.add_cascade(label="File",menu=file)
help = Menu(menubar, tearoff=0)
menubar.add_cascade(label="Help", menu=help)
help = Menu(menubar, tearoff=0)
m.config(menu=menubar)
tabControl= ttk.Notebook(m)
tab1=Frame(tabControl)
tab2=Frame(tabControl)
tabControl.add(tab1, text='Tab 1')
tabControl.add(tab2, text='Tab 2')
tabControl.pack(expand=1, fill="both")
Label(tab1,text="Hello").grid(row=1,column=0,padx=30,pady=30)
Label(tab2,text="The Snake",fg="blue").grid(row=0,column=0,padx=20,pady=10,sticky=W)
Checkbutton(tab2,text="Disabled").grid(row=1,column=0,padx=30,pady=10)
Checkbutton(tab2,text="UnChecked").grid(row=1,column=1,padx=20,pady=10)
Checkbutton(tab2,text="Enabled").grid(row=1,column=2,padx=10,pady=10)
t=IntVar()
Radiobutton(tab2,text="Blue",variable=t,value="Blue").place(x=30,y=97)
Radiobutton(tab2,text="Gold",variable=t,value="Gold").place(x=153,y=97)
Radiobutton(tab2,text="Red",variable=t,value="Red").place(x=272,y=97)
Label(tab2,text="ProgressBar",fg="blue").place(x=40,y=137)
a=Button(tab2,text="Run Progressbar",width=15).place(x=38,y=162)
b=Button(tab2,text="Stop Progressbar",width=15).place(x=38,y=192)
c=Button(tab2,text="Stop immediately",width=15).place(x=38,y=222)
d=Button(tab2,text="Stop after second",width=15).place(x=38,y=252)
pb= ttk.Progressbar(tab2,orient='horizontal',length=393)
pb['value']=30
pb.place(x=28,y=300)
m.mainloop()
